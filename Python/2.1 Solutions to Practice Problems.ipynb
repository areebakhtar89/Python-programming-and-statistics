# %% [markdown]
# # Lesson 02 - Sample Solution to Practice Problems

# %% [markdown]
# 1. Write a Python expression to check if the number 365 lies in the interval 300 to 400

# %%
365 >= 300 and 365 <= 400
# Out:
# True

# %%
300 <= 365 <= 400    # Alternate way of writing the above expression, much more readable
# Out:
# True

# %% [markdown]
# ***

# %% [markdown]
# 1. Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
a = int(input("Enter Age for a: "))
b = int(input("Enter Age for b: "))
c = int(input("Enter Age for c: "))

if  a <= b and a <= c:
    print("a is youngest")
    if b>=c:
        print("b is the oldest")
    else:
        print("c is the oldest")
elif  b <= a and b <= c:
    print("b is youngest")
    if a>=c:
        print("a is the oldest")
    else:
        print("c is the oldest")
else:
    print("c is the youngest")
    if b>=a:
        print("b is the oldest")
    else:
        print("a is the oldest")
# Out:
# Enter Age for a: 1
# Enter Age for b: 2
# Enter Age for c: 3
# a is youngest
# c is the oldest

# %% [markdown]
# ***

# %% [markdown]
# 2. A school has following rules for grading system:
# > Below 25 - F <br>
# > 25 to 45 - E <br>
# > 45 to 50 - D <br>
# > 50 to 60 - C <br>
# > 60 to 80 - B <br>
# > Above 80 - A <br>
# > Ask user to enter marks and print the corresponding grade.

# %%
print("Enter marks")
marks = int(input())

if marks < 25:
    print("Grade: F")
elif marks >= 25 and marks < 45:
    print("Grade: E")
elif marks >= 45 and marks < 50:
    print("Grade: D")
elif marks >= 50 and marks < 60:
    print("Grade: C")
elif marks >= 60 and marks < 80:
    print("Grade: B")
else:
    print("Grade: A")
# Out:
# Enter marks
# 44
# Grade: E

# %% [markdown]
# ***

# %% [markdown]
# 3. Take two int values from user and print greatest among them.

# %%
print("Enter first number")
first = int(input())
print("Enter second number")
second = int(input())

if first > second:
    print("Greatest number is",first)
elif second > first:
    print ("Greatest number is",second)
else:
    print ("Both are equal!")
# Out:
# Enter first number
# 1
# Enter second number
# 1
# Both are equal!

# %% [markdown]
# ***

# %% [markdown]
# 4. Write a program to find if a given number is positive or negative.

# %%
num = 5
if num > 0:
    print(num, "is a positive number.")
elif num < 0:
    print(num, "is a negative number.")
else:
    print(num, "is Zero!")
# Out:
# 5 is a positive number.

# %% [markdown]
# ***

# %% [markdown]
# # for Loop

# %% [markdown]
# 1. Print all elements of a list using for loop.

# %%
a = [1,2,3,4,5]
for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ***

# %% [markdown]
# 2. Take 10 integers from keyboard using loop and print their average value on the screen.

# %%
sum = 0

i = 10
while i > 0:
    print("Enter a number")
    num = int(input())
    sum = sum + num
    i = i - 1
print("Average is", sum / 10.0)
# Out:
# Enter a number
# 1
# Enter a number
# 1
# Enter a number
# 1
# Enter a number
# 1
# Enter a number
# 1
# Enter a number
# 1
# Enter a number
# 1
# Enter a number
# 1
# Enter a number
# 1
# Enter a number
# 1
# Average is 1.0

# %% [markdown]
# ***

# %% [markdown]
# 3. Print multiplication table of 24, 50 and 29 using loop.

# %%
i = 1
while i <= 10:
    print('24 times', i, '=', 24 * i)
    i += 1
# Out:
# 24 times 1 = 24
# 24 times 2 = 48
# 24 times 3 = 72
# 24 times 4 = 96
# 24 times 5 = 120
# 24 times 6 = 144
# 24 times 7 = 168
# 24 times 8 = 192
# 24 times 9 = 216
# 24 times 10 = 240

# %% [markdown]
# ***

# %% [markdown]
# 4. Write an infinite loop. A inifinte loop never ends. Condition is always True.

# %%
# IMPORTANT NOTE: You will have to interrupt the kernel to stop this cell's execution
while True:
    print ("INFINITE")
# Out:
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# INFINITE
# ...

# %% [markdown]
# ***
